# %% [markdown]
# <a href="https://colab.research.google.com/github/AbdullahBera/Investigating-Netflix-Movies/blob/main/netflixanalysis.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
from google.colab import files
uploaded = files.upload()
# Out:
#      <input type="file" id="files-1ab36406-c591-4d57-858d-b031f04cdfdb" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-1ab36406-c591-4d57-858d-b031f04cdfdb">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script>// Copyright 2017 Google LLC
# //
# // Licensed under the Apache License, Version 2.0 (the "License");
# // you may not use this file except in compliance with the License.
# // You may obtain a copy of the License at
# //
# //      http://www.apache.org/licenses/LICENSE-2.0
# //
# // Unless required by applicable law or agreed to in writing, software
# // distributed under the License is distributed on an "AS IS" BASIS,
# // WITHOUT WARRANTIES OR CONDITIONS OF ANY KIND, either express or implied.
# // See the License for the specific language governing permissions and
# // limitations under the License.
#
# ...

# %%
# Importing pandas and matplotlib
import pandas as pd
import matplotlib.pyplot as plt
# Start coding!
netflix_df = pd.read_csv("netflix_data.csv")

# %%
netflix_df.head(7)
# Out:
#   show_id     type  title           director  \
# 0      s1  TV Show     3%                NaN
# 1      s2    Movie   7:19  Jorge Michel Grau
# 2      s3    Movie  23:59       Gilbert Chan
# 3      s4    Movie      9        Shane Acker
# 4      s5    Movie     21     Robert Luketic
# 5      s6  TV Show     46        Serdar Akar
# 6      s7    Movie    122    Yasir Al Yasiri
#
#                                                 cast        country  \
# 0  João Miguel, Bianca Comparato, Michel Gomes, R...         Brazil
# 1  Demián Bichir, Héctor Bonilla, Oscar Serrano, ...         Mexico
# 2  Tedd Chan, Stella Chung, Henley Hii, Lawrence ...      Singapore
# 3  Elijah Wood, John C. Reilly, Jennifer Connelly...  United States
# 4  Jim Sturgess, Kevin Spacey, Kate Bosworth, Aar...  United States
# 5  Erdal Beşikçioğlu, Yasemin Allen, Melis Birkan...         Turkey
# 6  Amina Khalil, Ahmed Dawood, Tarek Lotfy, Ahmed...          Egypt
#
#           date_added  release_year  duration  \
# ...

# %%
netflix_subset = netflix_df[netflix_df['type'] != "TV Show"]
print(netflix_subset.type.unique())
netflix_subset.head(5)
# Out:
# ['Movie']
#   show_id   type  title           director  \
# 1      s2  Movie   7:19  Jorge Michel Grau
# 2      s3  Movie  23:59       Gilbert Chan
# 3      s4  Movie      9        Shane Acker
# 4      s5  Movie     21     Robert Luketic
# 6      s7  Movie    122    Yasir Al Yasiri
#
#                                                 cast        country  \
# 1  Demián Bichir, Héctor Bonilla, Oscar Serrano, ...         Mexico
# 2  Tedd Chan, Stella Chung, Henley Hii, Lawrence ...      Singapore
# 3  Elijah Wood, John C. Reilly, Jennifer Connelly...  United States
# 4  Jim Sturgess, Kevin Spacey, Kate Bosworth, Aar...  United States
# 6  Amina Khalil, Ahmed Dawood, Tarek Lotfy, Ahmed...          Egypt
#
#           date_added  release_year  duration  \
# 1  December 23, 2016          2016        93
# 2  December 20, 2018          2011        78
# 3  November 16, 2017          2009        80
# 4    January 1, 2020          2008       123
# 6       June 1, 2020          2019        95
#
# ...

# %%
netflix_movies = netflix_subset[["title", "country", "genre", "release_year", "duration"]]
netflix_movies.head()
# Out:
#    title        country          genre  release_year  duration
# 1   7:19         Mexico         Dramas          2016        93
# 2  23:59      Singapore  Horror Movies          2011        78
# 3      9  United States         Action          2009        80
# 4     21  United States         Dramas          2008       123
# 6    122          Egypt  Horror Movies          2019        95

# %%
short_movies = netflix_movies[netflix_movies.duration < 60]
short_movies.head()
# Out:
#                                                  title        country  \
# 35                                           #Rucker50  United States
# 55                 100 Things to do Before High School  United States
# 67   13TH: A Conversation with Oprah Winfrey & Ava ...            NaN
# 101                                  3 Seconds Divorce         Canada
# 146                                     A 3 Minute Hug         Mexico
#
#              genre  release_year  duration
# 35   Documentaries          2016        56
# 55   Uncategorized          2014        44
# 67   Uncategorized          2017        37
# 101  Documentaries          2018        53
# 146  Documentaries          2019        28

# %%
colors = []

for value in netflix_movies["genre"]:
    if value == "Children":
        colors.append("Green")
    elif value == "Documentaries":
        colors.append("Blue")
    elif value == "Stand-Up":
        colors.append("Yellow")
    else:
        colors.append("Black")

# %%
fig = plt.figure(figsize=(12,8))

plt.scatter(netflix_movies.release_year, netflix_movies.duration, c = colors)

plt.xlabel("Release year")
plt.ylabel("Duration (min)")
plt.title("Movie Duration by Year of Release")
plt.show()

# %%
# !git init

# !git config --global user.name "AbdullahBera"
# !git config --global user.email "kucukabdullahbera@gmail.com"
# Out:
# Reinitialized existing Git repository in /content/Investigating-Netflix-Movies/Investigating-Netflix-Movies/Investigating-Netflix-Movies/Investigating-Netflix-Movies/Investigating-Netflix-Movies/.git/

# %%
# !git clone https://github.com/AbdullahBera/Investigating-Netflix-Movies.git
# Out:
# Cloning into 'Investigating-Netflix-Movies'...
# remote: Enumerating objects: 3, done.
# remote: Counting objects: 100% (3/3), done.
# remote: Total 3 (delta 0), reused 0 (delta 0), pack-reused 0
# Receiving objects: 100% (3/3), done.

# %%
# %cd Investigating-Netflix-Movies
# Out:
# /content/Investigating-Netflix-Movies/Investigating-Netflix-Movies/Investigating-Netflix-Movies/Investigating-Netflix-Movies/Investigating-Netflix-Movies/Investigating-Netflix-Movies

# %%
# !git status
# Out:
# On branch main
# Your branch is up to date with 'origin/main'.
#
# nothing to commit, working tree clean

# %%
# !git remote set-url origin https://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@github.com/AbdullahBera/Investigating-Netflix-Movies.git

# %%
# !git add .

# %%
# !git commit -m "DataCamp Python Code"
# Out:
# On branch main
# Your branch is up to date with 'origin/main'.
#
# nothing to commit, working tree clean

# %%
# !git push origin main
# Out:
# Everything up-to-date

# %%
# !git status
# Out:
# On branch main
# Your branch is up to date with 'origin/main'.
#
# nothing to commit, working tree clean

# %%
# !git add .

# %%
# !git commit -m "DataCamp Python Code"
# Out:
# On branch main
# Your branch is up to date with 'origin/main'.
#
# nothing to commit, working tree clean

# %%
# !git branch
# Out:
# * main

# %%
# !git branch -r
# Out:
#   origin/HEAD -> origin/main
#   origin/main

# %%
# !git push origin main
# Out:
# Everything up-to-date
